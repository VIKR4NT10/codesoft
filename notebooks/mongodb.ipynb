# %%
import pymongo
import certifi
from pymongo import MongoClient
from tqdm import tqdm

# %%
# MongoDB Atlas connection
MONGODB_URI = "mongodb+srv://vikrantschavan3_db_user:phcRoZI9ImCPXxin@cluster0.d0dk86t.mongodb.net/?appName=Cluster0"

client = MongoClient(
    MONGODB_URI,
    tlsCAFile=certifi.where()
)

db = client["capstone_db"]
collection = db["movie_genre"]

print("Connected to MongoDB Atlas")
# Out:
# Connected to MongoDB Atlas

# %%
FILE_PATH = "train_data.txt"

with open(FILE_PATH, "r", encoding="utf-8") as f:
    lines = f.readlines()

print(f"📄 Loaded {len(lines)} records")
# Out:
# 📄 Loaded 54214 records

# %%
lines[1]
# Out:
# '2 ::: Cupid (1997) ::: thriller ::: A brother and sister with a past incestuous relationship have a current murderous relationship. He murders the women who reject him and she murders the women who get too close to him.\n'

# %%
def parse_line(line: str) -> dict | None:
    parts = [p.strip() for p in line.split(":::")]

    if len(parts) != 4:
        return None  # skip malformed rows

    return {
        "movie_id": int(parts[0]),
        "title": parts[1],
        "genre": parts[2],
        "description": parts[3]
    }


documents = []

for line in tqdm(lines):
    doc = parse_line(line)
    if doc:
        documents.append(doc)

print(f"🧾 Parsed {len(documents)} valid documents")
# Out:
# ...
# 100%|██████████| 54214/54214 [00:00<00:00, 76667.64it/s]
# 🧾 Parsed 54214 valid documents

# %%
if documents:
    result = collection.insert_many(documents)
    print(f"Inserted {len(result.inserted_ids)} documents into MongoDB")
else:
    print("No documents to insert")
# Out:
# Inserted 54214 documents into MongoDB

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('697af7c2c9cd2be2fd6eaac7'),
#  'movie_id': 1,
#  'title': 'Oscar et la dame rose (2009)',
#  'genre': 'drama',
#  'description': 'Listening in to a conversation between his doctor and parents, 10-year-old Oscar learns what nobody has the courage to tell him. He only has a few weeks to live. Furious, he refuses to speak to anyone except straight-talking Rose, the lady in pink he meets on the hospital stairs. As Christmas approaches, Rose uses her fantastical experiences as a professional wrestler, her imagination, wit and charm to allow Oscar to live life and love to the full, in the company of his friends Pop Corn, Einstein, Bacon and childhood sweetheart Peggy Blue.'}

# %%
import pandas as pd
csv_file = "spam.csv"  # make sure this file exists in the same directory
df = pd.read_csv(csv_file, encoding="latin-1")

# Optional: preview data
print(df.head())
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
import pandas as pd
from pymongo import MongoClient
import certifi

# MongoDB Atlas connection
MONGODB_URI = "mongodb+srv://vikrantschavan3_db_user:phcRoZI9ImCPXxin@cluster0.d0dk86t.mongodb.net/?appName=Cluster0"

client = MongoClient(
    MONGODB_URI,
    tlsCAFile=certifi.where()
)

db = client["capstone_db"]
collection = db["spam_csv"]

print("Connected to MongoDB Atlas")
# Out:
# Connected to MongoDB Atlas

# %%
records = df.to_dict(orient="records")

if records:
    collection.insert_many(records)
    print(f"Inserted {len(records)} documents into 'spam_csv' collection")
else:
    print("CSV file is empty. Nothing inserted.")
# Out:
# Inserted 5572 documents into 'spam_csv' collection
