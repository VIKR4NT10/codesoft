# %%
import pandas as pd
import pymongo
import certifi
from pymongo import MongoClient
from datetime import datetime

# %%
MONGODB_URI = "mongodb+srv://vikrantschavan3_db_user:phcRoZI9ImCPXxin@cluster0.d0dk86t.mongodb.net/?appName=Cluster0"

client = MongoClient(
    MONGODB_URI,
    tlsCAFile=certifi.where()
)

db = client["capstone_db"]
collection = db["fraud_transactions"]

print("✅ Connected to MongoDB Atlas")
# Out:
# ✅ Connected to MongoDB Atlas

# %%
FILE_PATH = "cc_data.csv"

df = pd.read_csv(FILE_PATH)

print(f"📄 Loaded {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# 📄 Loaded 1852394 rows and 22 columns

# %%
df["trans_date_trans_time"] = pd.to_datetime(
    df["trans_date_trans_time"],
    errors="coerce"
)

# Optional: drop rows with bad dates
df = df.dropna(subset=["trans_date_trans_time"])

# %%
records = df.to_dict(orient="records")
print(f"📦 Prepared {len(records)} MongoDB documents")
# Out:
# 📦 Prepared 1852394 MongoDB documents

# %%
BATCH_SIZE = 10000  # 10k rows per batch
inserted = 0

for i in range(0, len(records), BATCH_SIZE):
    batch = records[i:i + BATCH_SIZE]
    collection.insert_many(batch)
    inserted += len(batch)
    print(f"✅ Inserted {inserted} / {len(records)} records")

print(f"🎉 All {inserted} records inserted successfully!")
# Out:
# ✅ Inserted 10000 / 1852394 records
# ✅ Inserted 20000 / 1852394 records
# ✅ Inserted 30000 / 1852394 records
# ✅ Inserted 40000 / 1852394 records
# ✅ Inserted 50000 / 1852394 records
# ✅ Inserted 60000 / 1852394 records
# ✅ Inserted 70000 / 1852394 records
# ✅ Inserted 80000 / 1852394 records
# ✅ Inserted 90000 / 1852394 records
# ✅ Inserted 100000 / 1852394 records
# ✅ Inserted 110000 / 1852394 records
# ✅ Inserted 120000 / 1852394 records
# ✅ Inserted 130000 / 1852394 records
# ✅ Inserted 140000 / 1852394 records
# ✅ Inserted 150000 / 1852394 records
# ✅ Inserted 160000 / 1852394 records
# ✅ Inserted 170000 / 1852394 records
# ✅ Inserted 180000 / 1852394 records
# ✅ Inserted 190000 / 1852394 records
# ✅ Inserted 200000 / 1852394 records
# ✅ Inserted 210000 / 1852394 records
# ✅ Inserted 220000 / 1852394 records
# ✅ Inserted 230000 / 1852394 records
# ✅ Inserted 240000 / 1852394 records
# ✅ Inserted 250000 / 1852394 records
# ✅ Inserted 260000 / 1852394 records
# ✅ Inserted 270000 / 1852394 records
# ✅ Inserted 280000 / 1852394 records
# ✅ Inserted 290000 / 1852394 records
# ✅ Inserted 300000 / 1852394 records
# ✅ Inserted 310000 / 1852394 records
# ✅ Inserted 320000 / 1852394 records
# ✅ Inserted 330000 / 1852394 records
# ✅ Inserted 340000 / 1852394 records
# ✅ Inserted 350000 / 1852394 records
# ✅ Inserted 360000 / 1852394 records
# ✅ Inserted 370000 / 1852394 records
# ✅ Inserted 380000 / 1852394 records
# ✅ Inserted 390000 / 1852394 records
# ✅ Inserted 400000 / 1852394 records
# ✅ Inserted 410000 / 1852394 records
# ✅ Inserted 420000 / 1852394 records
# ✅ Inserted 430000 / 1852394 records
# ✅ Inserted 440000 / 1852394 records
# ✅ Inserted 450000 / 1852394 records
# ✅ Inserted 460000 / 1852394 records
# ✅ Inserted 470000 / 1852394 records
# ✅ Inserted 480000 / 1852394 records
# ✅ Inserted 490000 / 1852394 records
# ✅ Inserted 500000 / 1852394 records
# ✅ Inserted 510000 / 1852394 records
# ✅ Inserted 520000 / 1852394 records
# ✅ Inserted 530000 / 1852394 records
# ✅ Inserted 540000 / 1852394 records
# ✅ Inserted 550000 / 1852394 records
# ✅ Inserted 560000 / 1852394 records
# ✅ Inserted 570000 / 1852394 records
# ✅ Inserted 580000 / 1852394 records
# ✅ Inserted 590000 / 1852394 records
# ✅ Inserted 600000 / 1852394 records
# ✅ Inserted 610000 / 1852394 records
# ✅ Inserted 620000 / 1852394 records
# ✅ Inserted 630000 / 1852394 records
# ✅ Inserted 640000 / 1852394 records
# ✅ Inserted 650000 / 1852394 records
# ✅ Inserted 660000 / 1852394 records
# ✅ Inserted 670000 / 1852394 records
# ✅ Inserted 680000 / 1852394 records
# ✅ Inserted 690000 / 1852394 records
# ✅ Inserted 700000 / 1852394 records
# ✅ Inserted 710000 / 1852394 records
# ✅ Inserted 720000 / 1852394 records
# ✅ Inserted 730000 / 1852394 records
# ✅ Inserted 740000 / 1852394 records
# ✅ Inserted 750000 / 1852394 records
# ✅ Inserted 760000 / 1852394 records
# ✅ Inserted 770000 / 1852394 records
# ✅ Inserted 780000 / 1852394 records
# ✅ Inserted 790000 / 1852394 records
# ✅ Inserted 800000 / 1852394 records
# ✅ Inserted 810000 / 1852394 records
# ✅ Inserted 820000 / 1852394 records
# ✅ Inserted 830000 / 1852394 records
# ✅ Inserted 840000 / 1852394 records
# ✅ Inserted 850000 / 1852394 records
# ✅ Inserted 860000 / 1852394 records
# ✅ Inserted 870000 / 1852394 records
# ✅ Inserted 880000 / 1852394 records
# ✅ Inserted 890000 / 1852394 records
# ✅ Inserted 900000 / 1852394 records
# ✅ Inserted 910000 / 1852394 records
# ✅ Inserted 920000 / 1852394 records
# ✅ Inserted 930000 / 1852394 records
# ✅ Inserted 940000 / 1852394 records
# ✅ Inserted 950000 / 1852394 records
# ✅ Inserted 960000 / 1852394 records
# ✅ Inserted 970000 / 1852394 records
# ✅ Inserted 980000 / 1852394 records
# ✅ Inserted 990000 / 1852394 records
# ✅ Inserted 1000000 / 1852394 records
# ✅ Inserted 1010000 / 1852394 records
# ✅ Inserted 1020000 / 1852394 records
# ✅ Inserted 1030000 / 1852394 records
# ✅ Inserted 1040000 / 1852394 records
# ✅ Inserted 1050000 / 1852394 records
# ✅ Inserted 1060000 / 1852394 records
# ✅ Inserted 1070000 / 1852394 records
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[23], line 6
#       4 for i in range(0, len(records), BATCH_SIZE):
#       5     batch = records[i:i + BATCH_SIZE]
# ----> 6     collection.insert_many(batch)
#       7     inserted += len(batch)
#       8     print(f"✅ Inserted {inserted} / {len(records)} records")
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
#     756 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\bulk.py:576, in _Bulk.execute(self, write_concern, session)
#     574         return None
#     575 else:
# --> 576     return self.execute_command(generator, write_concern, session)
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\bulk.py:443, in _Bulk.execute_command(self, generator, write_concern, session)
#     432     self._execute_command(
#     433         generator,
#     434         write_concern,
#    (...)
#     439         full_result,
#     440     )
#     442 client = self.collection.database.client
# --> 443 client._retryable_write(self.is_retryable, retryable_bulk, session, bulk=self)
#     445 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     446     _raise_bulk_write_error(full_result)
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\bulk.py:432, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     429 def retryable_bulk(
#     430     session: Optional[ClientSession], conn: Connection, retryable: bool
#     431 ) -> None:
# --> 432     self._execute_command(
#     433         generator,
#     434         write_concern,
#     435         session,
#     436         conn,
#     437         op_id,
#     438         retryable,
#     439         full_result,
#     440     )
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\bulk.py:378, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     376 # Run as many ops as possible in one command.
#     377 if write_concern.acknowledged:
# --> 378     result, to_send = bwc.execute(cmd, ops, client)
#     380     # Retryable writeConcernErrors halt the execution of this run.
#     381     wce = result.get("writeConcernError", {})
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\message.py:964, in _BulkWriteContext.execute(self, cmd, docs, client)
#     960 def execute(
#     961     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]], client: MongoClient
#     962 ) -> tuple[Mapping[str, Any], list[Mapping[str, Any]]]:
#     963     request_id, msg, to_send = self.__batch_command(cmd, docs)
# --> 964     result = self.write_command(cmd, request_id, msg, to_send)
#     965     client._process_response(result, self.session)
#     966     return result, to_send
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\message.py:1058, in _BulkWriteContext.write_command(self, cmd, request_id, msg, docs)
#    1056     start = datetime.datetime.now()
#    1057 try:
# -> 1058     reply = self.conn.write_command(request_id, msg, self.codec)
#    1059     if self.publish:
#    1060         duration = (datetime.datetime.now() - start) + duration
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\pool.py:1060, in Connection.write_command(self, request_id, msg, codec_options)
#    1057 result = reply.command_response(codec_options)
#    1059 # Raises NotPrimaryError or OperationFailure.
# -> 1060 helpers._check_command_response(result, self.max_wire_version)
#    1061 return result
#
# File c:\Users\DELL\.conda\envs\titan\lib\site-packages\pymongo\helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: you are over your space quota, using 519 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 519 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}

# %%
collection.drop()

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('697387c76578a7e85123e00b'),
#  'trans_date_trans_time': datetime.datetime(2019, 1, 1, 0, 0, 18),
#  'cc_num': 2703186189652095,
#  'merchant': 'fraud_Rippin, Kub and Mann',
#  'category': 'misc_net',
#  'amt': 4.97,
#  'first': 'Jennifer',
#  'last': 'Banks',
#  'gender': 'F',
#  'street': '561 Perry Cove',
#  'city': 'Moravian Falls',
#  'state': 'NC',
#  'zip': 28654,
#  'lat': 36.0788,
#  'long': -81.1781,
#  'city_pop': 3495,
#  'job': 'Psychologist, counselling',
#  'dob': '1988-03-09',
#  'trans_num': '0b242abb623afc578575680df30655b9',
#  'unix_time': 1325376018,
#  'merch_lat': 36.011293,
#  'merch_long': -82.048315,
#  'is_fraud': 0}
